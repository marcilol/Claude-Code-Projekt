# %% [markdown]
# <a href="https://colab.research.google.com/github/marcilol/Claude-Code-Projekt/blob/master/Colab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/marcilol/Claude-Code-Projekt.git
# Out:
# Cloning into 'Claude-Code-Projekt'...
# remote: Enumerating objects: 321, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 321 (delta 3), reused 0 (delta 0), pack-reused 309 (from 1)
# Receiving objects: 100% (321/321), 62.36 MiB | 22.13 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# Updating files: 100% (309/309), done.

# %%
# %cd Claude-Code-Projekt
# Out:
# /content/Claude-Code-Projekt

# %%
# !python scripts/analyze_portfolio.py data/input/portfolios/Own_Portfolio_dated.csv
# Out:
# ======================================================================
# PORTFOLIO RISK DECOMPOSITION - BARRA FACTOR MODEL
# ======================================================================
#
# Loading portfolio: data/input/portfolios/Own_Portfolio_dated.csv
#   Found 28 positions
#
# Fetching current prices and calculating weights...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: AVIO"}}}
#   Successfully priced 27 positions
#   Total portfolio value: $26,689
#
# Loading factor exposures...
# Traceback (most recent call last):
#   File "/content/Claude-Code-Projekt/scripts/analyze_portfolio.py", line 395, in <module>
#     main(portfolio_path)
#   File "/content/Claude-Code-Projekt/scripts/analyze_portfolio.py", line 215, in main
#     factor_exp_df = pd.read_csv('data/model/russell3000_factor_exposures_historical.csv')
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine
#     self.handles = get_handle(
#                    ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/common.py", line 873, in get_handle
#     handle = open(
#              ^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'data/model/russell3000_factor_exposures_historical.csv'
